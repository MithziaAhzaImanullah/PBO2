# %%
class mahasiswa:
    def __init__(self, nama, nim, krs):
        self.nama = nama
        self.nim = nim
        self.krs = krs

def main():
    mhs = mahasiswa("Mithzia Ahza Imannullah", 230705134, "Keamanan Jaringan, PBO, Sistem Operasi Lanjut")

    print("Nama:", mhs.nama)
    print("NIM:", mhs.nim)
    print("KRS:", mhs.krs)

if __name__ == '__main__':
    main()
# Out:
# Nama: Mithzia Ahza Imannullah
# NIM: 230705134
# KRS: Keamanan Jaringan, PBO, Sistem Operasi Lanjut
